# %% [markdown]
# # Grid Search Completo - Detecção de Toxicidade
#
# Este notebook executa o `run_grid_search` programaticamente, evitando problemas com argumentos de linha de comando no Jupyter.

# %%
import sys
import os
import logging

# Adiciona raiz do projeto ao PATH
project_root = os.path.abspath(os.path.join(os.getcwd()))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

from app.nlp.training.train_toxicity_gridsearch import run_grid_search

# Configura logging para visualizar progresso aqui no notebook
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(name)s - %(levelname)s - %(message)s',
    force=True
)

# %% [markdown]
# ## Execução
# O comando abaixo iniciará o Grid Search Completo (16 configurações).
# **Atenção:** Isso pode levar dias dependendo do hardware.

# %%
# Executa Grid Search (SEM pré-processamento)
# Defina mode='full' para o grid completo ou 'fast' para teste rápido
run_grid_search(mode='full', preprocess=False)

# %% [markdown]
# ## Avaliação Final
# Após o término do treinamento, execute a célula abaixo para avaliar o modelo final no conjunto de teste.

# %%
# !python -m app.nlp.evaluation.evaluate_toxicity
